# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device yang digunakan: {device}")
# Out:
# Device yang digunakan: cpu

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
import torch.nn as nn
import torch.optim as optim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ganti ini sesuai nama folder dataset Anda di Google Drive
path_dataset = "/content/drive/MyDrive/dataset"  # ganti jika nama folder beda

# Transformasi dasar
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Load dataset
dataset = ImageFolder(root=path_dataset, transform=transform)

# Split jadi train & val
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Tampilkan info kelas
print(f"Label kelas: {dataset.classes}")
print(f"Jumlah gambar total: {len(dataset)} (train: {train_size}, val: {val_size})")
# Out:
# Label kelas: ['pohon_jambu', 'pohon_kelapa', 'pohon_mangga', 'pohon_pisang']
# Jumlah gambar total: 1246 (train: 996, val: 250)

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)  # input: 3 channel RGB
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(32 * 16 * 16, num_classes)  # 64x64 >> 32x32 >> 16x16

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 32 * 16 * 16)  # Flatten
        x = self.fc1(x)
        return x

# Inisialisasi model
num_classes = len(dataset.classes)
model = SimpleCNN(num_classes).to(device)

print(model)
# Out:
# SimpleCNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=8192, out_features=4, bias=True)
# )

# %%
# Loss function dan optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Langkah 4: Definisikan Model CNN Ringan
import torch
import torch.nn as nn  # Pastikan import nn
from torchvision import transforms
from torchvision.datasets import ImageFolder

# Menggunakan path dataset yang sesuai
# Ganti dengan lokasi dataset Anda jika berbeda
path_dataset = "/content/drive/MyDrive/dataset"  # Pastikan path sudah benar

# Definisikan transformasi untuk preprocessing gambar
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize gambar ke ukuran 64x64
    transforms.ToTensor(),        # Konversi gambar ke tensor
    transforms.Normalize((0.5,), (0.5,))  # Normalisasi gambar
])

# Menggunakan ImageFolder untuk membaca dataset
dataset = ImageFolder(root=path_dataset, transform=transform)

# Inisialisasi jumlah kelas
num_classes = len(dataset.classes)
device = "cuda" if torch.cuda.is_available() else "cpu"

# Definisikan model CNN
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)  # input: 3 channel RGB
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(32 * 16 * 16, num_classes)  # 64x64 >> 32x32 >> 16x16

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 32 * 16 * 16)  # Flatten
        x = self.fc1(x)
        return x

# Inisialisasi model
model = SimpleCNN(num_classes).to(device)

# Menampilkan model
print(model)
# Out:
# SimpleCNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=8192, out_features=4, bias=True)
# )

# %%
# Langkah 3: Siapkan Transformasi dan Load Dataset
from torchvision import transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

# Ganti path_dataset dengan lokasi folder dataset Anda di Google Drive
path_dataset = "/content/drive/MyDrive/dataset"  # Ganti dengan path dataset Anda

# Transformasi untuk preprocessing gambar
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Resize gambar ke ukuran 64x64
    transforms.ToTensor(),        # Konversi gambar ke tensor
    transforms.Normalize((0.5,), (0.5,))  # Normalisasi gambar
])

# Load dataset menggunakan ImageFolder
dataset = ImageFolder(root=path_dataset, transform=transform)

# Split dataset menjadi data train dan validasi
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# DataLoader untuk batch training dan validasi
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Menampilkan jumlah kelas dan jumlah gambar
print(f"Label kelas: {dataset.classes}")
print(f"Jumlah gambar total: {len(dataset)} (train: {train_size}, val: {val_size})")
# Out:
# Label kelas: ['pohon_jambu', 'pohon_kelapa', 'pohon_mangga', 'pohon_pisang']
# Jumlah gambar total: 1246 (train: 996, val: 250)

# %%
# Langkah 7: Mulai Pelatihan Model
# Menggunakan kode yang sudah didefinisikan sebelumnya untuk melatih model

num_epochs = 5  # Anda bisa menyesuaikan jumlah epoch sesuai kebutuhan
train_losses, val_accuracies = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs)

# Menampilkan grafik akurasi dan loss (optional)
import matplotlib.pyplot as plt

# Plot Train Loss
plt.plot(train_losses, label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss per Epoch')
plt.legend()
plt.show()

# Plot Validation Accuracy
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy per Epoch')
plt.legend()
plt.show()
# Out:
# Epoch 1/5, Train Loss: 1.3443, Train Accuracy: 0.3685, Val Accuracy: 0.3600
# Epoch 2/5, Train Loss: 1.1898, Train Accuracy: 0.4739, Val Accuracy: 0.4840
# Epoch 3/5, Train Loss: 1.0390, Train Accuracy: 0.5602, Val Accuracy: 0.4960
# Epoch 4/5, Train Loss: 0.9517, Train Accuracy: 0.6124, Val Accuracy: 0.5440
# Epoch 5/5, Train Loss: 0.8370, Train Accuracy: 0.6787, Val Accuracy: 0.5600
